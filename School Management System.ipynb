# %% [markdown]
# <a href="https://colab.research.google.com/github/Usman-938/Management-System/blob/main/School%20Management%20System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [Train a CNN to classify handwritten digits on the MNIST dataset using Flax NNX API](https://colab.research.google.com/github/google/flax/blob/main/docs_nnx/mnist_tutorial.ipynb)
# - [Train a Vision Transformer (ViT) for image classification with JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_Vision_transformer.ipynb)
# - [Text classification with a transformer language model using JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_transformer_text_classification.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Train a miniGPT language model with JAX AI Stack](https://docs.jaxstack.ai/en/latest/JAX_for_LLM_pretraining.html)
# - [LoRA/QLoRA finetuning for LLM using Tunix](https://github.com/google/tunix/blob/main/examples/qlora_gemma.ipynb)
# - [Parameter-efficient fine-tuning of Gemma with LoRA and QLoRA](https://keras.io/examples/keras_recipes/parameter_efficient_finetuning_of_gemma_with_lora_and_qlora/)
# - [Loading Hugging Face Transformers Checkpoints](https://keras.io/keras_hub/guides/hugging_face_keras_integration/)
# - [8-bit Integer Quantization in Keras](https://keras.io/guides/int8_quantization_in_keras/)
# - [Float8 training and inference with a simple Transformer model](https://keras.io/examples/keras_recipes/float8_training_and_inference_with_transformer/)
# - [Pretraining a Transformer from scratch with KerasHub](https://keras.io/keras_hub/guides/transformer_pretraining/)
# - [Simple MNIST convnet](https://keras.io/examples/vision/mnist_convnet/)
# - [Image classification from scratch using Keras 3](https://keras.io/examples/vision/image_classification_from_scratch/)
# - [Image Classification with KerasHub](https://keras.io/keras_hub/guides/classification_with_keras_hub/)

# %%
import numpy as np

arr = np.array([5, 10, 15, 20, 25])

total_sum = np.sum(arr)
mean_value = np.mean(arr)
max_value = np.max(arr)

print("Sum:", total_sum)
print("Mean:", mean_value)
print("Maximum:", max_value)
# Out:
# Sum: 75
# Mean: 15.0
# Maximum: 25

# %%
import pandas as pd

# Create DataFrame (table)
table = {
    "Student Name": ["Ali", "Ahmed", "Sara"],
    "Age": [20, 21, 19],
    "Marks": [85, 90, 88]
}

df = pd.DataFrame(table)

# Display full table
print("Student Table:")
print(df)

# Display only Marks column
print("\nMarks Column:")
print(df[["Marks"]])
# Out:
# Student Table:
#   Student Name  Age  Marks
# 0          Ali   20     85
# 1        Ahmed   21     90
# 2         Sara   19     88
#
# Marks Column:
#    Marks
# 0     85
# 1     90
# 2     88

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-29055556.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("dataset.csv")
#       3 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Create a dummy DataFrame
dummy_data = {
    'Student Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [20, 21, 19, 22, 20],
    'Marks': [85, 90, 88, 92, 87]
}
dummy_df = pd.DataFrame(dummy_data)

# Save the dummy DataFrame to 'dataset.csv'
dummy_df.to_csv('dataset.csv', index=False)

print("Dummy 'dataset.csv' created successfully.")
# Out:
# Dummy 'dataset.csv' created successfully.

# %% [markdown]
# If you have your own `dataset.csv` file, you can upload it by clicking the 'Files' icon on the left sidebar (looks like a folder icon), then clicking the 'Upload to session storage' icon (looks like a page with an arrow pointing up). Make sure to upload it to the main content directory, not a subdirectory, or adjust the `pd.read_csv` path accordingly.

# %%
/students.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1310072633.py in <cell line: 0>()
# ----> 1 students.csv()
#
# NameError: name 'students' is not defined

# %%
import pandas as pd

# Assuming students.csv is in the current directory or /content/
df_students = pd.read_csv('students.csv')
display(df_students.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2254114541.py in <cell line: 0>()
#       2
#       3 # Assuming students.csv is in the current directory or /content/
# ----> 4 df_students = pd.read_csv('students.csv')
#       5 display(df_students.head())
#
# ...

# %%
import pandas as pd

df = pd.read_csv('dataset.csv')
display(df.head())
# Out:
#   Student Name  Age  Marks
# 0        Alice   20     85
# 1          Bob   21     90
# 2      Charlie   19     88
# 3        David   22     92
# 4          Eve   20     87

# %%
df = pd.read_csv("students.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3067145114.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("students.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
/students.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-563115124.py in <cell line: 0>()
# ----> 1 students.csv()
#
# NameError: name 'students' is not defined

# %%
df.shape
df.columns
df.info()
df.describe()

import pandas as pd
df = pd.read_csv("dataset.csv")
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  5 non-null      object
#  1   Age           5 non-null      int64
#  2   Marks         5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
#   Student Name  Age  Marks
# 0        Alice   20     85
# 1          Bob   21     90
# 2      Charlie   19     88
# 3        David   22     92
# 4          Eve   20     87

# %%
df.describe()
# Out:
#              Age      Marks
# count   5.000000   5.000000
# mean   20.400000  88.400000
# std     1.140175   2.701851
# min    19.000000  85.000000
# 25%    20.000000  87.000000
# 50%    20.000000  88.000000
# 75%    21.000000  90.000000
# max    22.000000  92.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  5 non-null      object
#  1   Age           5 non-null      int64
#  2   Marks         5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.shape
# Out:
# (5, 3)

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with some missing values
students_data_with_missing = {
    'Student Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [20, np.nan, 19, 22, 20],
    'Marks': [85, 90, np.nan, 92, 87],
    'Attendance': [95, 88, 92, np.nan, 90]
}

df_students_missing = pd.DataFrame(students_data_with_missing)

# Save the DataFrame to a CSV file
df_students_missing.to_csv('students_missing_values.csv', index=False)

print("CSV file 'students_missing_values.csv' created successfully with missing values.")
display(df_students_missing.head())
# Out:
# CSV file 'students_missing_values.csv' created successfully with missing values.
#   Student Name   Age  Marks  Attendance
# 0        Alice  20.0   85.0        95.0
# 1          Bob   NaN   90.0        88.0
# 2      Charlie  19.0    NaN        92.0
# 3        David  22.0   92.0         NaN
# 4          Eve  20.0   87.0        90.0

# %%
df.isnull().sum()
# Out:
# Student Name    0
# Age             0
# Marks           0
# dtype: int64

# %%
df.dropna()
# Out:
#   Student Name  Age  Marks
# 0        Alice   20     85
# 1          Bob   21     90
# 2      Charlie   19     88
# 3        David   22     92
# 4          Eve   20     87

# %%
df.fillna(0)
# Out:
#   Student Name  Age  Marks
# 0        Alice   20     85
# 1          Bob   21     90
# 2      Charlie   19     88
# 3        David   22     92
# 4          Eve   20     87

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('students.csv')
df['Marks'].plot(kind='hist')
plt.show()

# %% [markdown]
# # Task
# I will now proceed with the following plan:
# * **Load Data**: Load the dataset into a pandas DataFrame.
# * **Generate Descriptive Statistics**: Calculate and display descriptive statistics for numerical columns (e.g., mean, median, std, min, max, quartiles) and value counts for categorical columns.
# * **Identify Missing Values**: Check for missing values in each column and display the count and percentage of missing data.
# * **Visualize Missing Values**: Create a bar plot or heatmap to visualize the distribution of missing values across the dataset, if any. Provide appropriate legends.
# * **Detect Outliers**: Use box plots to identify potential outliers in numerical columns. Provide appropriate legends.
# * **Visualize Distributions**: Generate histograms or kernel density plots for numerical columns to visualize their distributions. Provide appropriate legends.
# * **Analyze Relationships**: Create scatter plots for pairs of numerical variables to visualize their relationships. If there are categorical variables, consider pair plots or grouped box plots. Provide appropriate legends.
# * **Final Task**: Summarize the key findings from the automated EDA, including insights into data quality, distributions, and relationships between variables.
#
# I will start by loading the data into a pandas DataFrame.

# %% [markdown]
# ## Load Data
#
# ### Subtask:
# Load the dataset into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# The user wants to load the 'dataset.csv' file into a pandas DataFrame and display its head. This requires importing the pandas library, using `pd.read_csv()` to load the data, and then `df.head()` to show the first few rows.

# %%
import pandas as pd

df = pd.read_csv('students.csv')
display(df.head())
# Out:
#   Student Name  Age  Marks
# 0          Ali   20     85
# 1        Ahmed   21     90
# 2         Sara   19     88
# 3       Ayesha   22     92
# 4        Bilal   20     80

# %% [markdown]
# **Reasoning**:
# The previous code failed because `dataset.csv` was not found. I will correct the filename to `students.csv`, which is available in the kernel.

# %%
import pandas as pd

df = pd.read_csv('students.csv')
display(df.head())
# Out:
#   Student Name  Age  Marks
# 0          Ali   20     85
# 1        Ahmed   21     90
# 2         Sara   19     88
# 3       Ayesha   22     92
# 4        Bilal   20     80

# %% [markdown]
# **Reasoning**:
# The data has been successfully loaded into the DataFrame `df`. Now, I will generate and display descriptive statistics for numerical columns using `df.describe()` and value counts for categorical columns, as per the overall plan.

# %%
print("Descriptive Statistics for Numerical Columns:")
display(df.describe())

print("\nValue Counts for Categorical Columns:")
for col in df.select_dtypes(include='object').columns:
    print(f"\nValue counts for column '{col}':")
    display(df[col].value_counts())
# Out:
# Descriptive Statistics for Numerical Columns:
#              Age      Marks
# count   5.000000   5.000000
# mean   20.400000  87.000000
# std     1.140175   4.690416
# min    19.000000  80.000000
# 25%    20.000000  85.000000
# 50%    20.000000  88.000000
# 75%    21.000000  90.000000
# max    22.000000  92.000000
# Value Counts for Categorical Columns:
#
# Value counts for column 'Student Name':
# Student Name
# Ali       1
# Ahmed     1
# Sara      1
# Ayesha    1
# Bilal     1
# Name: count, dtype: int64

# %% [markdown]
# **Reasoning**:
# To identify missing values, I will use `df.isnull().sum()` to get the count of missing values for each column and then calculate the percentage of missing values.

# %%
print("Missing Values:")
missing_counts = df.isnull().sum()
display(missing_counts)

print("\nPercentage of Missing Values:")
missing_percentage = (df.isnull().sum() / len(df)) * 100
display(missing_percentage)
# Out:
# Missing Values:
# Student Name    0
# Age             0
# Marks           0
# dtype: int64
# Percentage of Missing Values:
# Student Name    0.0
# Age             0.0
# Marks           0.0
# dtype: float64

# %% [markdown]
# The current dataset `df` does not contain any missing values, as indicated by the previous output (`missing_counts` and `missing_percentage` are all zeros). Therefore, a visualization for missing values is not applicable. I will now move on to the next step: **Detect Outliers** using box plots for numerical columns.

# %% [markdown]
# **Reasoning**:
# To detect outliers, I will first identify the numerical columns in the DataFrame. Then, I will generate box plots for these numerical columns to visualize potential outliers, adding appropriate titles and labels for clarity.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

if not numerical_cols.empty:
    print("Box plots for numerical columns to detect outliers:")
    for col in numerical_cols:
        plt.figure(figsize=(6, 4))
        sns.boxplot(x=df[col])
        plt.title(f'Box Plot of {col}')
        plt.xlabel(col)
        plt.show()
else:
    print("No numerical columns found to detect outliers.")
# Out:
# Box plots for numerical columns to detect outliers:

# %% [markdown]
# **Reasoning**:
# The box plots have been displayed for numerical columns. Now, I will generate histograms for numerical columns to visualize their distributions, as per the overall plan.

# %%
print("Histograms for numerical columns to visualize distributions:")

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Histograms for numerical columns to visualize distributions:

# %% [markdown]
# **Reasoning**:
# The distributions of numerical columns have been visualized. Now, I will analyze relationships between numerical variables by creating scatter plots, as outlined in the overall plan.

# %%
print("Scatter plots for pairs of numerical variables to visualize relationships:")

if len(numerical_cols) > 1:
    sns.pairplot(df[numerical_cols])
    plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
    plt.show()
else:
    print("Not enough numerical columns to create scatter plots for relationships.")
# Out:
# Scatter plots for pairs of numerical variables to visualize relationships:

# %% [markdown]
# ## Summary of Key Findings from Automated EDA
#
# Based on the automated Exploratory Data Analysis performed:
#
# *   **Data Quality**: The dataset appears to be clean with **no missing values** and **no duplicate rows**. This indicates a good quality dataset for direct analysis.
#
# *   **Descriptive Statistics**: The numerical columns ('Age' and 'Marks') show summary statistics. 'Age' ranges from 19 to 22 with a mean of 20.4, while 'Marks' range from 80 to 92 with a mean of 87. The standard deviations are relatively small, indicating that values within these columns are not widely dispersed.
#
# *   **Outlier Detection**: The box plots for 'Age' and 'Marks' did not show any apparent outliers, suggesting that all data points fall within the expected ranges for this small dataset.
#
# *   **Distributions**: The histograms for 'Age' and 'Marks' show the distribution of these variables. 'Age' has a distribution centered around 20-21, with most students falling into these age groups. 'Marks' are also generally high, clustering around the 80s and 90s.
#
# *   **Relationships**: The pair plots (scatter plots) for 'Age' and 'Marks' show how these variables relate to each other. For this small dataset, there doesn't appear to be a strong linear correlation between 'Age' and 'Marks'. However, with more data points, a more definitive relationship could be observed.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the key findings from the automated EDA, including insights into data quality, distributions, and relationships between variables.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The key findings from the automated EDA are summarized below, covering data quality, distributions, and relationships between variables.
#
# ### Data Analysis Key Findings
# *   **Data Quality**: The dataset is high quality, with no missing values detected in any columns and no duplicate rows.
# *   **Descriptive Statistics**:
#     *   'Age' ranges from 19 to 22 years, with an average of 20.4 years. The standard deviation is relatively small, indicating a tight clustering of ages.
#     *   'Marks' range from 80 to 92, with an average of 87. Similar to age, the standard deviation for marks is small, suggesting consistent performance among the students.
# *   **Outlier Detection**: No apparent outliers were identified in either the 'Age' or 'Marks' columns through box plots, indicating all data points fall within expected ranges.
# *   **Distributions**:
#     *   The 'Age' distribution is centered primarily around 20-21 years.
#     *   The 'Marks' distribution shows a high concentration in the 80s and 90s, suggesting generally good academic performance.
# *   **Relationships**: For this small dataset, scatter plots of 'Age' versus 'Marks' did not reveal any strong linear correlation between the two numerical variables.
#
# ### Insights or Next Steps
# *   Given the small size of the dataset, conclusions drawn about relationships between variables should be interpreted with caution. Further analysis would benefit from a larger and more diverse dataset to confirm observed trends or uncover weaker correlations.
# *   Since the initial data quality is excellent, the dataset is immediately ready for more advanced modeling or hypothesis testing if the scope expands beyond basic EDA.

# %%
# !pip install ydata-profiling
from ydata_profiling import
# Out:
#   File "/tmp/ipython-input-4104723133.py", line 2
#     from ydata_profiling import
#                                ^
# SyntaxError: invalid syntax

# %%
# Student Management System
# Ready for Google Colab
# Stores student records in memory (list of dictionaries)

# List to store all students
students = []

# Function to add a student
def add_student():
    name = input("Enter student name: ")
    age = int(input("Enter student age: "))
    marks = float(input("Enter student marks: "))

    # Create a dictionary for a student
    student = {
        "name": name,
        "age": age,
        "marks": marks
    }

    students.append(student)
    print(f"Student '{name}' added successfully!\n")


# Function to view all students
def view_students():
    if not students:
        print("No students found.\n")
        return

    print("\n--- Student List ---")
    for i, student in enumerate(students, start=1):
        print(f"{i}. Name: {student['name']}, Age: {student['age']}, Marks: {student['marks']}")
    print()


# Function to search a student
def search_student():
    name = input("Enter student name to search: ")
    for student in students:
        if student["name"].lower() == name.lower():
            print(f"Found: Name: {student['name']}, Age: {student['age']}, Marks: {student['marks']}\n")
            return
    print("Student not found.\n")


# Function to update student marks
def update_student_marks():
    name = input("Enter student name to update marks: ")
    for student in students:
        if student["name"].lower() == name.lower():
            new_marks = float(input("Enter new marks: "))
            student["marks"] = new_marks
            print(f"Marks updated successfully for '{name}'!\n")
            return
    print("Student not found.\n")


# Function to delete a student
def delete_student():
    name = input("Enter student name to delete: ")
    for student in students:
        if student["name"].lower() == name.lower():
            students.remove(student)
            print(f"Student '{name}' deleted successfully!\n")
            return
    print("Student not found.\n")


# Main menu loop
def main():
    while True:
        print("===== Student Management System =====")
        print("1. Add Student")
        print("2. View All Students")
        print("3. Search Student")
        print("4. Update Student Marks")
        print("5. Delete Student")
        print("6. Exit")

        choice = input("Enter your choice (1-6): ")

        if choice == "1":
            add_student()
        elif choice == "2":
            view_students()
        elif choice == "3":
            search_student()
        elif choice == "4":
            update_student_marks()
        elif choice == "5":
            delete_student()
        elif choice == "6":
            print("Exiting program... Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.\n")

# Run the program
main()
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 1
# Enter student name: usman
# Enter student age: 22
# Enter student marks: 85
# Student 'usman' added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 1
# Enter student name: ahmad
# Enter student age: 20
# Enter student marks: 90
# Student 'ahmad' added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 2
#
# --- Student List ---
# 1. Name: usman, Age: 22, Marks: 85.0
# 2. Name: ahmad, Age: 20, Marks: 90.0
#
# ===== Student Management System =====
# 1. Add Student
# 2. View All Students
# 3. Search Student
# ...

# %%
students = []   # List to store all student records

# Function to calculate grade
def calculate_grade(marks):
    if marks >= 90:
        return "A"
    elif marks >= 80:
        return "B"
    elif marks >= 70:
        return "C"
    else:
        return "F"

# Function to add a student
def add_student():
    roll = input("Enter Roll Number: ")

    # Check if roll number already exists
    for student in students:
        if student["roll"] == roll:
            print("Student with this roll number already exists.")
            return

    name = input("Enter Name: ")
    dept = input("Enter Department: ")
    marks = int(input("Enter Marks: "))

    grade = calculate_grade(marks)

    student = {
        "roll": roll,
        "name": name,
        "department": dept,
        "marks": marks,
        "grade": grade
    }

    students.append(student)
    print("Student added successfully.")


# Function to view all students
def view_students():
    if len(students) == 0:
        print("No students found.")
    else:
        for student in students:
            print("----------------------")
            print("Roll Number:", student["roll"])
            print("Name:", student["name"])
            print("Department:", student["department"])
            print("Marks:", student["marks"])
            print("Grade:", student["grade"])
            print("----------------------")


# Function to search a student
def search_student():
    roll = input("Enter Roll Number to search: ")

    for student in students:
        if student["roll"] == roll:
            print("Student Found:")
            print("Roll Number:", student["roll"])
            print("Name:", student["name"])
            print("Department:", student["department"])
            print("Marks:", student["marks"])
            print("Grade:", student["grade"])
            return

    print("Student not found.")


# Function to update student marks
def update_marks():
    roll = input("Enter Roll Number to update marks: ")

    for student in students:
        if student["roll"] == roll:
            new_marks = int(input("Enter New Marks: "))
            student["marks"] = new_marks
            student["grade"] = calculate_grade(new_marks)
            print("Marks and grade updated successfully.")
            return

    print("Student not found.")


# Function to delete a student
def delete_student():
    roll = input("Enter Roll Number to delete: ")

    for student in students:
        if student["roll"] == roll:
            students.remove(student)
            print("Student deleted successfully.")
            return

    print("Student not found.")


# Main program loop
while True:
    print("\n--- Student Management System ---")
    print("1. Add Student")
    print("2. View All Students")
    print("3. Search Student")
    print("4. Update Student Marks")
    print("5. Delete Student")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "1":
        add_student()
    elif choice == "2":
        view_students()
    elif choice == "3":
        search_student()
    elif choice == "4":
        update_marks()
    elif choice == "5":
        delete_student()
    elif choice == "6":
        print("Exiting program. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# --- Student Management System ---
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 1
# Enter Roll Number: 1
# Enter Name: Ali
# Enter Department: CS
# Enter Marks: 75
# Student added successfully.
#
# --- Student Management System ---
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 1
# Enter Roll Number: 2
# Enter Name: Ahmad
# Enter Department: CS
# Enter Marks: 80
# Student added successfully.
#
# --- Student Management System ---
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Update Student Marks
# 5. Delete Student
# 6. Exit
# Enter your choice (1-6): 1
# Enter Roll Number: 3
# Enter Name: Usman
# Enter Department: CS
# Enter Marks: 90
# Student added successfully.
#
# --- Student Management System ---
# 1. Add Student
# 2. View All Students
# 3. Search Student
# ...
